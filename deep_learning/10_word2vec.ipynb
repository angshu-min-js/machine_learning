# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
#print(words)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  print (count[:5])
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary) #Indexing
    #print (dictionary) {'and': 3, 'of': 2, 'the': 1, 'UNK': 0}
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# [['UNK', -1], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  #print ('buffer: ',buffer)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    #print ('data_index: ',data_index)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'term', 'as', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  print("Embeddings shape: ", embeddings.get_shape())
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
  print("softmax_weights: ", softmax_weights.get_shape())
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  print("softmax_biases: ", softmax_biases.get_shape())
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print("embed: ", embed.get_shape())
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))
  print("loss: ", loss.get_shape())

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Embeddings shape:  TensorShape([Dimension(50000), Dimension(128)])
# softmax_weights:  TensorShape([Dimension(50000), Dimension(128)])
# softmax_biases:  TensorShape([Dimension(50000)])
# embed:  TensorShape([Dimension(128), Dimension(128)])
# loss:  TensorShape([])

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.896099
# Nearest to also: anakin, torquato, explore, whirlpool, jack, preferences, paideia, frankie,
# Nearest to about: abundance, duplicating, holdings, laoco, carefully, akayev, tampere, tongues,
# Nearest to most: kimmei, aliphatic, selecting, asean, becket, ineffectual, zuid, gssp,
# Nearest to no: genital, downstream, implying, scrooge, rosa, chaotic, stakeholders, vampyre,
# Nearest to used: kulaks, malls, declarative, atmospheric, comparing, collectivist, powerhouse, emanations,
# Nearest to nine: amide, mca, batavian, erin, kampaku, friesian, springsteen, malfunctions,
# Nearest to there: verily, gadamer, soloists, vespucci, amelia, nugget, orphan, prelude,
# Nearest to only: obi, searched, mppc, thrust, tallest, cochrane, nervous, karelia,
# Nearest to by: henriques, hamath, engagements, lucien, poorer, emulates, patronymic, vessel,
# Nearest to use: acts, benn, irvin, religiously, contaminated, erasing, hazlitt, waive,
# Nearest to not: prospective, perennially, popped, isaacs, postcards, renga, thujone, prevention,
# Nearest to an: reunions, monty, inconvenient, proleptic, lordship, dabbled, klimt, bodhi,
# Nearest to at: heinlein, rebuttal, advaita, upholding, beanstalk, araki, covenants, respiration,
# Nearest to during: moulin, jogaila, charioteer, imitate, berglin, ignition, wyclif, outperform,
# Nearest to up: cyborg, chats, hissing, ski, tanganyika, wi, likeness, navigator,
# Nearest to in: capoeiristas, putting, ctv, grossly, wushu, oeuvre, mistresses, croydon,
# Average loss at step 2000: 4.361106
# Average loss at step 4000: 3.859012
# Average loss at step 6000: 3.796251
# Average loss at step 8000: 3.689592
# Average loss at step 10000: 3.616185
# Nearest to also: which, vespers, now, he, it, who, generally, anakin,
# Nearest to about: rounded, laoco, naturalist, cena, seize, carefully, allergy, au,
# Nearest to most: teenage, zuid, ux, clermont, pharaonic, unavoidable, flavorings, daikaiju,
# Nearest to no: it, add, genital, reunified, tested, ambition, implying, available,
# Nearest to used: known, held, wiley, found, kulaks, galbraith, worrying, burrow,
# Nearest to nine: eight, zero, six, five, seven, three, four, two,
# Nearest to there: it, vespucci, not, still, ayatollah, radiocommunication, they, avowed,
# Nearest to only: schaff, modena, cochrane, obi, will, thrust, fearing, raining,
# Nearest to by: was, alh, been, onerous, with, were, on, be,
# Nearest to use: domingo, levellers, nederlandse, irvin, benn, crawling, valour, mosiah,
# Nearest to not: they, there, starving, it, silk, often, to, never,
# Nearest to an: motionless, lordship, dabbled, kennedy, brasses, hydroxybutyrate, proleptic, monty,
# Nearest to at: in, on, for, petitioner, by, innodb, deification, valved,
# Nearest to during: through, in, charioteer, moulin, mike, researches, outperform, first,
# Nearest to up: cyborg, chats, hissing, profited, identify, clp, likeness, relay,
# Nearest to in: of, on, at, with, during, from, intensively, and,
# Average loss at step 12000: 3.602544
# Average loss at step 14000: 3.570814
# Average loss at step 16000: 3.407527
# Average loss at step 18000: 3.456702
# Average loss at step 20000: 3.545325
# Nearest to also: which, now, generally, often, not, who, vespers, there,
# Nearest to about: rounded, au, evolves, ghanaian, bituminous, backwardness, laoco, carefully,
# Nearest to most: many, ux, more, pharaonic, all, some, central, constricted,
# Nearest to no: available, implying, add, a, reunified, tested, scrooge, it,
# Nearest to used: held, known, found, wiley, galbraith, kulaks, determined, seen,
# Nearest to nine: eight, six, seven, four, zero, five, three, two,
# Nearest to there: it, they, he, which, still, ayatollah, also, not,
# Nearest to only: schaff, jinn, karelia, cochrane, pete, modena, ust, badges,
# Nearest to by: be, with, was, been, alh, into, emulates, through,
# Nearest to use: levellers, price, crawling, domingo, nederlandse, supersonic, benn, irvin,
# Nearest to not: it, starving, never, still, also, to, there, they,
# Nearest to an: lordship, motionless, hydroxybutyrate, kennedy, foxy, the, slayer, lefebvre,
# Nearest to at: in, on, innodb, including, for, transonic, is, leitrim,
# Nearest to during: in, through, burgnich, following, globalsecurity, mike, researches, moulin,
# Nearest to up: chats, profited, identify, cyborg, hissing, relay, haight, dwell,
# Nearest to in: at, on, from, during, between, intensively, with, under,
# Average loss at step 22000: 3.496150
# Average loss at step 24000: 3.489333
# Average loss at step 26000: 3.482048
# Average loss at step 28000: 3.482281
# Average loss at step 30000: 3.505444
# Nearest to also: often, generally, now, still, who, bombed, which, it,
# Nearest to about: rounded, last, gags, bituminous, happiest, backwardness, over, stenella,
# Nearest to most: many, more, some, constricted, pharaonic, ux, daikaiju, widget,
# Nearest to no: any, a, unexpectedly, add, tested, little, filo, shocks,
# Nearest to used: known, found, seen, held, galbraith, determined, regarded, involved,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to there: they, it, he, still, who, which, not, also,
# Nearest to only: jobs, schaff, interacting, pete, bluffs, it, ust, antecedent,
# Nearest to by: videogame, alh, under, with, from, in, genet, through,
# Nearest to use: crawling, price, levellers, expansion, valour, wooing, computational, form,
# Nearest to not: still, they, starving, you, never, emotionally, there, it,
# Nearest to an: foxy, motionless, lordship, dabbled, kennedy, islas, apo, ikea,
# Nearest to at: in, during, before, on, innodb, after, lamo, participles,
# Nearest to during: in, through, after, at, burgnich, researches, jeb, mike,
# Nearest to up: off, chats, profited, identify, fleeing, them, vcjd, con,
# Nearest to in: during, at, of, under, on, between, after, until,
# Average loss at step 32000: 3.501225
# Average loss at step 34000: 3.494774
# Average loss at step 36000: 3.456468
# Average loss at step 38000: 3.300907
# Average loss at step 40000: 3.425607
# Nearest to also: often, now, generally, which, sometimes, usually, still, bombed,
# Nearest to about: rounded, over, auguste, swelling, stenella, evolves, on, agony,
# Nearest to most: more, many, daikaiju, some, less, zuid, constricted, foodstuffs,
# Nearest to no: any, add, a, magnetite, animations, ftl, westchester, tested,
# Nearest to used: known, found, seen, determined, addition, referred, regarded, spoken,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to there: it, they, he, which, still, usually, also, often,
# Nearest to only: jobs, always, thrust, prolong, not, it, transsexualism, ust,
# Nearest to by: emulates, when, was, for, with, onerous, hermeticism, playground,
# Nearest to use: price, computational, form, crawling, mobilization, levellers, result, expansion,
# Nearest to not: still, they, never, it, also, emotionally, always, usually,
# Nearest to an: lordship, hydroxybutyrate, dabbled, foxy, motionless, misunderstood, kennedy, mudd,
# Nearest to at: during, on, innodb, before, ascendant, olof, palladius, coincident,
# Nearest to during: after, through, at, in, jeb, first, globalsecurity, when,
# Nearest to up: them, off, out, slum, profited, chats, bromwich, fleeing,
# Nearest to in: since, within, of, from, catalysed, during, and, on,
# Average loss at step 42000: 3.431866
# Average loss at step 44000: 3.450270
# Average loss at step 46000: 3.453877
# Average loss at step 48000: 3.353047
# Average loss at step 50000: 3.380283
# Nearest to also: now, often, which, still, sometimes, generally, typically, actually,
# Nearest to about: auguste, over, rounded, ghanaian, autonomic, gags, swelling, stiles,
# Nearest to most: more, many, less, some, daikaiju, zuid, unavoidable, indymedia,
# Nearest to no: any, little, heschel, magnetite, ammanati, add, animations, reunified,
# Nearest to used: known, found, seen, referred, written, regarded, determined, possible,
# Nearest to nine: eight, seven, six, four, three, zero, five, two,
# Nearest to there: they, it, he, still, which, she, havoc, stimulated,
# Nearest to only: bluffs, typically, always, usually, satiric, cocoon, within, still,
# Nearest to by: through, with, under, was, without, from, during, jeb,
# Nearest to use: price, expansion, result, form, course, introduction, computational, mobilization,
# Nearest to not: never, still, they, usually, it, iniquity, almost, emotionally,
# Nearest to an: dabbled, lordship, foxy, kennedy, another, motionless, the, hydroxybutyrate,
# Nearest to at: on, during, palladius, near, before, valved, permits, leitrim,
# Nearest to during: after, in, through, jeb, enciphered, when, globalsecurity, at,
# Nearest to up: off, them, out, down, slum, chats, him, fleeing,
# Nearest to in: since, during, on, from, of, and, yelled, between,
# Average loss at step 52000: 3.435948
# Average loss at step 54000: 3.426795
# Average loss at step 56000: 3.436510
# Average loss at step 58000: 3.392715
# Average loss at step 60000: 3.395195
# Nearest to also: still, now, generally, often, typically, sometimes, below, which,
# Nearest to about: seperate, rounded, thermal, ghanaian, over, autonomic, powerbook, auguste,
# Nearest to most: many, some, more, daikaiju, indymedia, constricted, less, ore,
# Nearest to no: any, little, magnetite, conn, a, filo, ammanati, diagonally,
# Nearest to used: known, found, referred, written, seen, held, defined, designed,
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to there: they, it, he, still, this, now, she, often,
# Nearest to only: always, bluffs, usually, still, typically, jinn, worry, yet,
# Nearest to by: with, through, without, winnipeg, aguilera, engagements, under, from,
# Nearest to use: because, wings, success, form, introduction, result, struggle, method,
# Nearest to not: still, never, usually, starving, they, always, you, it,
# Nearest to an: lordship, dabbled, foxy, motionless, crespigny, hydroxybutyrate, kennedy, another,
# Nearest to at: before, in, after, tempest, near, lamo, moor, leitrim,
# Nearest to during: after, following, before, jeb, in, although, globalsecurity, until,
# Nearest to up: off, out, down, them, chats, slum, mithraic, dba,
# Nearest to in: since, within, of, between, during, until, including, on,
# Average loss at step 62000: 3.236381
# Average loss at step 64000: 3.259982
# Average loss at step 66000: 3.398985
# Average loss at step 68000: 3.397540
# Average loss at step 70000: 3.358639
# Nearest to also: now, still, generally, which, often, sometimes, actually, typically,
# Nearest to about: rounded, regarding, auguste, patriot, symbolizes, that, over, ghanaian,
# Nearest to most: many, more, less, some, zuid, especially, halfback, indymedia,
# Nearest to no: any, little, nonsensical, kissed, magnetite, already, conn, animations,
# Nearest to used: known, found, written, designed, seen, cited, regarded, referred,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to there: they, it, he, still, havoc, we, she, now,
# Nearest to only: always, still, ust, usually, yet, jinn, bluffs, secularism,
# Nearest to by: through, syncretic, be, lucien, from, winnipeg, emulates, was,
# Nearest to use: form, introduction, because, success, expansion, struggle, wings, computational,
# Nearest to not: never, still, now, easily, always, often, nothing, also,
# Nearest to an: motionless, lordship, dabbled, foxy, mudd, kennedy, unido, hydroxybutyrate,
# Nearest to at: during, implies, after, on, before, pu, near, cryptosystems,
# Nearest to during: after, in, before, following, jeb, through, until, werke,
# Nearest to up: off, out, them, down, fleeing, slum, mithraic, chats,
# Nearest to in: within, during, until, since, on, from, among, throughout,
# Average loss at step 72000: 3.372982
# Average loss at step 74000: 3.345864
# Average loss at step 76000: 3.310730
# Average loss at step 78000: 3.352257
# Average loss at step 80000: 3.379238
# Nearest to also: now, still, often, sometimes, which, generally, actually, never,
# Nearest to about: autonomic, auguste, patriot, rounded, over, swelling, evolves, metcalfe,
# Nearest to most: many, more, some, less, cantons, especially, biotechnology, daikaiju,
# Nearest to no: little, any, arabella, nonsensical, conn, kissed, starling, stringent,
# Nearest to used: known, found, referred, seen, written, regarded, defined, designed,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to there: they, it, he, she, still, now, this, havoc,
# Nearest to only: always, jobs, bluffs, worry, cocoon, usually, satiric, secularism,
# Nearest to by: playground, through, with, was, aguilera, lucien, gland, when,
# Nearest to use: because, form, introduction, wings, trajectory, success, macedon, struggle,
# Nearest to not: still, never, always, they, starving, emotionally, actually, it,
# Nearest to an: dabbled, lordship, motionless, foxy, kennedy, dyslexic, hydroxybutyrate, reunions,
# Nearest to at: on, tempest, in, after, studded, darling, before, during,
# Nearest to during: after, in, when, before, through, jeb, werke, until,
# Nearest to up: off, out, down, them, fleeing, slum, away, chats,
# Nearest to in: during, on, within, since, until, throughout, between, at,
# Average loss at step 82000: 3.402654
# Average loss at step 84000: 3.416604
# Average loss at step 86000: 3.387119
# Average loss at step 88000: 3.349300
# Average loss at step 90000: 3.366074
# Nearest to also: still, now, often, generally, sometimes, which, actually, gradually,
# Nearest to about: auguste, regarding, autonomic, swelling, paleocene, patriot, symbolizes, ku,
# Nearest to most: more, many, less, some, especially, daikaiju, cantons, biotechnology,
# Nearest to no: any, little, already, kissed, starling, conn, tested, arabella,
# Nearest to used: known, found, referred, designed, seen, applied, regarded, attributed,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to there: they, it, he, she, still, now, we, greenblatt,
# Nearest to only: always, therefore, faerie, ust, bluffs, hulme, even, worry,
# Nearest to by: without, using, with, through, playground, when, under, from,
# Nearest to use: because, success, introduction, support, macedon, manual, share, intervention,
# Nearest to not: never, still, emotionally, we, there, they, nothing, actually,
# Nearest to an: dabbled, lordship, foxy, motionless, slayer, sinai, rotors, carcasses,
# Nearest to at: on, during, in, tempest, implies, around, near, genet,
# Nearest to during: after, in, before, when, werke, through, although, jeb,
# Nearest to up: off, out, down, them, back, away, fleeing, together,
# Nearest to in: during, within, with, from, at, under, on, of,
# Average loss at step 92000: 3.398891
# Average loss at step 94000: 3.256269
# Average loss at step 96000: 3.360153
# Average loss at step 98000: 3.240114
# Average loss at step 100000: 3.353231
# Nearest to also: still, sometimes, now, actually, generally, often, never, bombed,
# Nearest to about: on, paleocene, bryn, auguste, ghanaian, rounded, swelling, actus,
# Nearest to most: more, less, especially, many, quintessence, some, daikaiju, biotechnology,
# Nearest to no: any, little, starling, magnetite, reunified, heschel, tested, already,
# Nearest to used: found, referred, designed, held, seen, known, defined, regarded,
# Nearest to nine: seven, eight, six, four, five, zero, three, two,
# Nearest to there: they, he, it, she, still, now, greenblatt, generally,
# Nearest to only: always, therefore, faerie, even, still, teleport, tumor, cocoon,
# Nearest to by: without, when, through, rowan, using, lucien, for, engagements,
# Nearest to use: trajectory, introduction, because, computational, macedon, nuisance, form, share,
# Nearest to not: never, still, emotionally, always, almost, simply, equal, generally,
# Nearest to an: dabbled, lordship, foxy, motionless, slayer, graft, another, megiddo,
# Nearest to at: during, on, near, in, innodb, unrounded, genet, tempest,
# Nearest to during: after, in, through, following, before, throughout, despite, at,
# Nearest to up: off, out, down, back, them, slum, away, him,
# Nearest to in: within, during, until, on, from, throughout, near, under,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_cbow_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        labels[i] = buffer[skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i][j] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    cbow_batch, cbow_labels = generate_cbow_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[bi] for bi in skips] for skips in cbow_batch])
    print('    labels:', [reverse_dictionary[li] for li in cbow_labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['as', 'anarchism'], ['a', 'originated'], ['as', 'term'], ['of', 'a'], ['abuse', 'term'], ['of', 'first'], ['abuse', 'used'], ['against', 'first']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'of', 'as', 'term'], ['as', 'a', 'abuse', 'of'], ['a', 'first', 'abuse', 'term'], ['term', 'of', 'used', 'first'], ['used', 'against', 'of', 'abuse'], ['early', 'against', 'abuse', 'first'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [raw]
# Train a CBOW model

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  print("Embeddings shape: ", embeddings.get_shape())
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
  print("softmax_weights: ", softmax_weights.get_shape())
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  print("softmax_biases: ", softmax_biases.get_shape())
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.reduce_sum(tf.nn.embedding_lookup(embeddings, train_dataset), 1)
  print("embed: ", embed.get_shape())
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))
  print("loss: ", loss.get_shape())

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Embeddings shape:  TensorShape([Dimension(50000), Dimension(128)])
# softmax_weights:  TensorShape([Dimension(50000), Dimension(128)])
# softmax_biases:  TensorShape([Dimension(50000)])
# embed:  TensorShape([Dimension(128), Dimension(128)])
# loss:  TensorShape([])

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.531060
# Nearest to this: andr, horizon, ligny, colour, sen, implausible, testable, heritage,
# Nearest to only: iras, individuals, lysander, combination, films, slide, demonstrably, automobile,
# Nearest to were: ecologists, regained, foederati, slices, mainstays, meritocracy, mikhailovich, derogatory,
# Nearest to been: pernambuco, stalemate, fares, intellectualism, mamluks, bookmarks, nephi, collectibles,
# Nearest to eight: pulau, ordain, stooges, flavours, casing, lynching, arrests, hsuan,
# Nearest to three: smit, humility, stews, hypermedia, liable, sombre, rijndael, warren,
# Nearest to many: emiliano, suisse, of, peta, mostly, neuro, rana, anacletus,
# Nearest to s: originator, mechanized, give, ahijah, nationally, lycanthropy, phonemically, fencer,
# Nearest to known: aho, stimulating, francium, rs, hemorrhagic, rules, onboard, save,
# Nearest to will: abdali, plus, butterfield, childress, compound, westphalia, stone, uploading,
# Nearest to so: browse, swung, colossians, rosemary, informatics, maestro, hin, mmu,
# Nearest to state: whitewater, geezer, leftist, doubt, cornwell, aster, martin, adobe,
# Nearest to system: burying, gygax, warming, gregg, unfamiliar, gonads, amicable, invading,
# Nearest to first: time, worldwide, villa, laing, separations, microgravity, repetitive, pudding,
# Nearest to years: potos, acapulco, foam, vlaanderen, controlling, nayla, compostela, footage,
# Nearest to when: vcrs, eucharist, seneca, sussex, ottawa, lagenorhynchus, lawfully, truer,
# Average loss at step 2000: 4.462980
# Average loss at step 4000: 3.778149
# Average loss at step 6000: 3.590333
# Average loss at step 8000: 3.436657
# Average loss at step 10000: 3.370752
# Nearest to this: the, unconnected, andr, edited, occidentalis, ligny, sancta, drown,
# Nearest to only: lysander, blondes, unorthodox, individuals, vibration, slide, trask, demonstrably,
# Nearest to were: are, is, was, larynx, logician, foederati, ecologists, devil,
# Nearest to been: pernambuco, bookmarks, fares, bins, mamluks, stalemate, micas, intellectualism,
# Nearest to eight: nine, three, six, zero, seven, four, gaelic, backronym,
# Nearest to three: eight, defections, hypermedia, helping, mama, excellent, scholastics, fox,
# Nearest to many: prester, reject, assortment, mostly, peta, cocker, aldrin, eyewitness,
# Nearest to s: and, maga, stuntman, nationally, lycanthropy, ah, mechanized, formative,
# Nearest to known: uncontrollably, injectors, rs, stimulating, fraught, save, rules, dogbert,
# Nearest to will: westphalia, bissau, can, brownlow, abdali, megaliths, cannot, terribly,
# Nearest to so: swung, rosemary, televangelist, luxemburg, hin, browse, mmu, colossians,
# Nearest to state: whitewater, martin, geezer, aster, adobe, leftist, adhemar, seeger,
# Nearest to system: burying, gygax, gonads, gregg, barber, warming, amicable, proselytes,
# Nearest to first: time, congressional, repetitive, supermassive, worldwide, villa, salon, moods,
# Nearest to years: potos, art, universal, iphigenia, acapulco, people, aluminum, compostela,
# Nearest to when: seneca, ottawa, vcrs, billings, bubblegum, position, eurostar, kayaks,
# Average loss at step 12000: 3.403200
# Average loss at step 14000: 3.343599
# Average loss at step 16000: 3.361269
# Average loss at step 18000: 3.316030
# Average loss at step 20000: 3.211536
# Nearest to this: the, unconnected, it, which, andr, that, accreditation, edited,
# Nearest to only: blondes, individuals, unorthodox, demonstrably, lysander, ttir, vibration, goin,
# Nearest to were: are, was, have, larynx, is, logician, ecologists, foederati,
# Nearest to been: pernambuco, be, bookmarks, bins, extracting, intellectualism, fares, was,
# Nearest to eight: six, nine, seven, five, three, four, zero, two,
# Nearest to three: eight, six, five, four, seven, two, defections, mama,
# Nearest to many: prester, mostly, some, reject, these, guevara, peta, wreck,
# Nearest to s: nationally, formative, ah, his, stuntman, ionospheric, icbms, maga,
# Nearest to known: uncontrollably, injectors, fraught, save, geraldine, well, rs, draugr,
# Nearest to will: can, would, cannot, westphalia, should, must, could, may,
# Nearest to so: televangelist, swung, rosemary, hin, proclus, luxemburg, mmu, intercontinental,
# Nearest to state: whitewater, martin, geezer, leftist, bolshevism, aster, doubt, adhemar,
# Nearest to system: gygax, burying, gonads, barber, proselytes, sales, aged, aversion,
# Nearest to first: repetitive, congressional, worldwide, villa, supermassive, time, moods, reflectors,
# Nearest to years: potos, iphigenia, aluminum, universal, art, people, dryden, oils,
# Nearest to when: seneca, billings, ottawa, vcrs, diesel, eurostar, here, as,
# Average loss at step 22000: 3.263170
# Average loss at step 24000: 3.227952
# Average loss at step 26000: 3.192904
# Average loss at step 28000: 3.219344
# Average loss at step 30000: 3.195796
# Nearest to this: it, which, the, unconnected, that, accreditation, edited, andr,
# Nearest to only: individuals, goin, ttir, door, blondes, wisdom, sulphate, lysander,
# Nearest to were: are, was, have, had, larynx, been, be, is,
# Nearest to been: be, pernambuco, was, become, were, extracting, bins, intellectualism,
# Nearest to eight: nine, six, seven, four, five, three, two, zero,
# Nearest to three: five, two, six, four, seven, eight, defections, nine,
# Nearest to many: some, these, prester, other, mostly, reject, guevara, enforceable,
# Nearest to s: nationally, formative, his, summing, ah, ionospheric, stuntman, complaining,
# Nearest to known: uncontrollably, injectors, well, such, fraught, geraldine, save, rs,
# Nearest to will: would, can, cannot, could, must, should, may, westphalia,
# Nearest to so: televangelist, rosemary, proclus, swung, hin, luxemburg, intercontinental, mmu,
# Nearest to state: whitewater, martin, geezer, bolshevism, aster, leftist, adhemar, remarried,
# Nearest to system: gygax, burying, gonads, proselytes, sales, barber, aged, safin,
# Nearest to first: congressional, repetitive, worldwide, villa, moods, supermassive, cusp, chemnitz,
# Nearest to years: potos, aluminum, universal, people, iphigenia, oils, dryden, fausto,
# Nearest to when: seneca, billings, because, here, diesel, ottawa, as, lumi,
# Average loss at step 32000: 3.051842
# Average loss at step 34000: 3.161744
# Average loss at step 36000: 3.137846
# Average loss at step 38000: 3.140540
# Average loss at step 40000: 3.127126
# Nearest to this: which, it, unconnected, that, accreditation, the, unsatisfactory, imbolc,
# Nearest to only: ttir, sulphate, goin, wisdom, door, individuals, relieving, vibration,
# Nearest to were: are, have, was, had, be, been, larynx, overlooked,
# Nearest to been: be, become, pernambuco, were, was, extracting, iconostasis, bins,
# Nearest to eight: six, nine, seven, five, four, three, zero, semites,
# Nearest to three: five, six, two, four, seven, eight, nine, zero,
# Nearest to many: some, these, several, mostly, other, all, such, most,
# Nearest to s: nationally, formative, ionospheric, summing, harbor, stuntman, his, ah,
# Nearest to known: uncontrollably, defined, injectors, well, such, regarded, used, fraught,
# Nearest to will: would, can, cannot, may, must, could, should, westphalia,
# Nearest to so: televangelist, rosemary, heckel, intercontinental, however, proclus, compaor, swung,
# Nearest to state: whitewater, adhemar, geezer, martin, bolshevism, aster, seeger, tackle,
# Nearest to system: gygax, burying, gonads, proselytes, sales, safin, barber, aged,
# Nearest to first: repetitive, congressional, limerick, worldwide, villa, second, moods, supermassive,
# Nearest to years: aluminum, potos, iphigenia, people, universal, oils, dryden, fausto,
# Nearest to when: because, seneca, billings, diesel, although, powerhouse, consider, here,
# Average loss at step 42000: 3.140802
# Average loss at step 44000: 3.138032
# Average loss at step 46000: 3.102488
# Average loss at step 48000: 3.075526
# Average loss at step 50000: 3.050658
# Nearest to this: which, it, the, accreditation, that, unconnected, some, unsatisfactory,
# Nearest to only: ttir, wisdom, sulphate, mech, nhk, goin, accommodations, demonstrably,
# Nearest to were: are, have, was, had, been, be, larynx, is,
# Nearest to been: be, become, were, was, pernambuco, extracting, being, frauds,
# Nearest to eight: nine, seven, six, four, five, zero, three, essai,
# Nearest to three: four, six, five, two, seven, eight, helping, defections,
# Nearest to many: some, several, these, all, most, such, mostly, other,
# Nearest to s: nationally, formative, ionospheric, harbor, summing, his, liquified, telomeres,
# Nearest to known: defined, uncontrollably, such, used, injectors, regarded, fraught, well,
# Nearest to will: would, can, may, must, could, cannot, should, westphalia,
# Nearest to so: televangelist, rosemary, however, intercontinental, heckel, compaor, luc, swung,
# Nearest to state: whitewater, bolshevism, states, adhemar, seeger, aster, martin, tackle,
# Nearest to system: gygax, burying, proselytes, gonads, sales, barber, systems, safin,
# Nearest to first: second, limerick, repetitive, worldwide, congressional, chemnitz, villa, moods,
# Nearest to years: aluminum, potos, iphigenia, people, oils, universal, howe, colleen,
# Nearest to when: because, although, against, after, powerhouse, if, diesel, before,
# Average loss at step 52000: 3.086020
# Average loss at step 54000: 3.057331
# Average loss at step 56000: 3.056694
# Average loss at step 58000: 2.957717
# Average loss at step 60000: 3.023601
# Nearest to this: it, which, unconnected, accreditation, the, one, qigong, some,
# Nearest to only: ttir, wisdom, hellene, still, totoro, enumeration, vibration, demonstrably,
# Nearest to were: are, have, was, had, been, be, curtailing, burgundians,
# Nearest to been: be, become, were, was, pernambuco, being, extracting, frauds,
# Nearest to eight: nine, six, seven, five, four, three, two, zero,
# Nearest to three: four, five, six, two, seven, eight, ase, zero,
# Nearest to many: some, several, these, all, most, such, mostly, those,
# Nearest to s: nationally, formative, ionospheric, harbor, deconstructing, summing, his, liquified,
# Nearest to known: defined, used, such, uncontrollably, regarded, injectors, follows, geraldine,
# Nearest to will: would, can, may, could, must, cannot, should, might,
# Nearest to so: televangelist, compaor, heckel, luxemburg, luc, swung, discipline, intercontinental,
# Nearest to state: whitewater, states, adhemar, aster, mares, olympias, bolshevism, dramas,
# Nearest to system: systems, burying, gygax, proselytes, sales, jackal, barber, aged,
# Nearest to first: second, limerick, repetitive, last, congressional, worldwide, taoiseach, chemnitz,
# Nearest to years: aluminum, potos, oils, iphigenia, days, people, universal, howe,
# Nearest to when: because, if, although, after, before, powerhouse, while, against,
# Average loss at step 62000: 3.035023
# Average loss at step 64000: 2.969163
# Average loss at step 66000: 2.954388
# Average loss at step 68000: 2.910917
# Average loss at step 70000: 2.971345
# Nearest to this: which, it, unconnected, accreditation, that, the, qigong, another,
# Nearest to only: ttir, hellene, both, enumeration, wisdom, still, mech, certainly,
# Nearest to were: are, have, was, had, been, be, curtailing, derelict,
# Nearest to been: be, become, were, was, pernambuco, being, frauds, extracting,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to three: five, four, seven, six, two, eight, zero, nine,
# Nearest to many: some, several, these, all, most, those, such, mostly,
# Nearest to s: nationally, formative, his, ionospheric, summing, harbor, deconstructing, originator,
# Nearest to known: defined, used, regarded, such, follows, uncontrollably, injectors, geraldine,
# Nearest to will: would, can, may, could, must, should, cannot, might,
# Nearest to so: televangelist, compaor, ao, however, discipline, luc, luxemburg, nkvd,
# Nearest to state: states, whitewater, bolshevism, adhemar, olympias, mares, dramas, aster,
# Nearest to system: systems, proselytes, gygax, burying, jackal, sales, mingling, aged,
# Nearest to first: second, limerick, last, repetitive, same, chemnitz, congressional, third,
# Nearest to years: aluminum, days, oils, potos, iphigenia, times, howe, year,
# Nearest to when: if, because, although, though, before, after, while, during,
# Average loss at step 72000: 2.995966
# Average loss at step 74000: 2.856967
# Average loss at step 76000: 2.997411
# Average loss at step 78000: 3.020624
# Average loss at step 80000: 2.971512
# Nearest to this: which, it, unconnected, that, accreditation, the, some, qigong,
# Nearest to only: ttir, hellene, wisdom, enumeration, demonstrably, still, first, both,
# Nearest to were: are, have, was, had, been, be, curtailing, zorro,
# Nearest to been: become, be, were, was, pernambuco, frauds, extracting, being,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to three: four, five, two, six, eight, seven, vindicated, nine,
# Nearest to many: some, several, these, most, all, those, such, other,
# Nearest to s: nationally, formative, harbor, his, hybridized, pcbs, deconstructing, telomeres,
# Nearest to known: used, defined, regarded, such, follows, uncontrollably, geraldine, fraught,
# Nearest to will: would, can, may, could, must, should, cannot, might,
# Nearest to so: compaor, televangelist, luc, ao, discipline, nkvd, nevertheless, luxemburg,
# Nearest to state: states, whitewater, adhemar, mares, bolshevism, guard, olympias, donnelly,
# Nearest to system: systems, burying, sales, proselytes, gygax, jackal, mingling, taif,
# Nearest to first: second, last, limerick, repetitive, same, third, latter, painterly,
# Nearest to years: days, aluminum, times, oils, year, iphigenia, potos, howe,
# Nearest to when: if, because, although, before, while, after, though, during,
# Average loss at step 82000: 2.865723
# Average loss at step 84000: 2.961356
# Average loss at step 86000: 2.933012
# Average loss at step 88000: 2.944530
# Average loss at step 90000: 2.933226
# Nearest to this: which, it, the, accreditation, unconnected, that, another, unsatisfactory,
# Nearest to only: ttir, wisdom, first, still, hellene, always, enumeration, rue,
# Nearest to were: are, have, had, was, been, be, curtailing, although,
# Nearest to been: become, be, were, pernambuco, was, frauds, extracting, being,
# Nearest to eight: six, seven, nine, five, four, three, zero, two,
# Nearest to three: four, five, two, six, eight, seven, vindicated, zero,
# Nearest to many: some, several, these, all, most, those, such, both,
# Nearest to s: nationally, formative, isbn, harbor, his, ionospheric, hybridized, accra,
# Nearest to known: defined, used, regarded, follows, such, uncontrollably, geraldine, intended,
# Nearest to will: would, can, may, could, must, cannot, should, might,
# Nearest to so: compaor, nevertheless, luc, televangelist, nkvd, less, samantha, discipline,
# Nearest to state: states, whitewater, mares, olympias, bolshevism, guard, donnelly, adhemar,
# Nearest to system: systems, sales, burying, mingling, proselytes, taif, gygax, gonads,
# Nearest to first: second, last, limerick, third, repetitive, latter, same, next,
# Nearest to years: days, aluminum, times, year, months, oils, centuries, novoselic,
# Nearest to when: if, although, because, while, before, though, after, during,
# Average loss at step 92000: 2.879687
# Average loss at step 94000: 2.926006
# Average loss at step 96000: 2.897854
# Average loss at step 98000: 2.576326
# Average loss at step 100000: 2.616963
# Nearest to this: which, it, accreditation, some, the, another, unconnected, ives,
# Nearest to only: first, ttir, wisdom, hellene, enumeration, demonstrably, scurvy, still,
# Nearest to were: are, have, was, had, been, be, is, being,
# Nearest to been: become, be, were, pernambuco, was, frauds, being, extracting,
# Nearest to eight: nine, seven, six, four, five, zero, three, undermines,
# Nearest to three: four, five, seven, six, two, eight, defections, ase,
# Nearest to many: some, several, all, these, most, those, such, various,
# Nearest to s: nationally, formative, isbn, his, deconstructing, harbor, summing, ionospheric,
# Nearest to known: defined, used, regarded, such, follows, geraldine, intended, uncontrollably,
# Nearest to will: would, can, may, could, must, should, cannot, might,
# Nearest to so: compaor, nevertheless, less, luc, nkvd, ao, discipline, televangelist,
# Nearest to state: states, whitewater, bolshevism, donnelly, mares, adhemar, guard, theo,
# Nearest to system: systems, burying, sales, mingling, taif, jackal, proselytes, gonads,
# Nearest to first: second, last, limerick, third, same, latter, next, only,
# Nearest to years: days, year, aluminum, months, times, centuries, oils, novoselic,
# Nearest to when: if, although, before, after, because, while, though, during,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
