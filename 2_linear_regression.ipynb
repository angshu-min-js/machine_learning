# %%
import numpy as np

num_points = 1000
vector_set = []
for i in xrange (num_points):
    xl = np.random.normal(0.0,0.55)
    yl = xl *0.1 + 0.3 + np.random.normal(.0,.03)
    vector_set.append([xl,yl])
    
x_data = [v[0] for v in vector_set]
y_data = [v[1] for v in vector_set]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(x_data, y_data, 'ro', label='original data')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import tensorflow as tf

W = tf.Variable(tf.random_uniform([1],-1.,1))
b = tf.Variable(tf.zeros([1]))

##init = tf.initialize_all_variables()
#sess = tf.Session()
#sess.run(init)
#v = sess.run(b)
#print v

y = W * x_data + b

# %%
loss = tf.reduce_mean(tf.square(y - y_data))

# %%
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

# %%
init = tf.initialize_all_variables()
 
sess = tf.Session()
sess.run(init)

# %%
# %matplotlib inline
for step in xrange(15):
   sess.run(train)
   print step, sess.run(W), sess.run(b)
   plt.plot(x_data, y_data, 'ro')
   plt.plot(x_data, sess.run(W)* x_data + sess.run(b))
   plt.legend()
   plt.show()
# Out:
# 0 [ 0.67919731] [ 0.31182307]
# 1 [ 0.51534617] [ 0.30820554]
# 2 [ 0.39798817] [ 0.30568928]
# 3 [ 0.31393191] [ 0.30388704]
# 4 [ 0.25372761] [ 0.30259618]
# 5 [ 0.21060699] [ 0.30167162]
# 6 [ 0.17972235] [ 0.30100942]
# 7 [ 0.15760161] [ 0.30053511]
# 8 [ 0.14175789] [ 0.30019543]
# 9 [ 0.13041002] [ 0.29995209]
# 10 [ 0.12228224] [ 0.29977784]
# 11 [ 0.11646082] [ 0.29965302]
# 12 [ 0.11229129] [ 0.29956362]
# 13 [ 0.10930492] [ 0.29949957]
# 14 [ 0.10716596] [ 0.29945374]

# %%
plt.plot(x_data, y_data, 'rx')
plt.plot(x_data, sess.run(W)* x_data + sess.run(b))
plt.xlabel('W')
plt.ylim(-2,2)
plt.ylabel('b')
plt.ylim(.1,.6)
plt.legend()
plt.show()
